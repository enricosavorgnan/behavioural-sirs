# %% [markdown]
# # Calculus

# %%
import numpy as np

from code.core.old.models import SIRSModels

# %%
mu = 1 / 80 / 365
gamma = 1 / 14
theta = 1 / 365
r0 = 2
beta = r0 * (mu + gamma)

alpha = 1
k = 1
q = gamma / (mu + theta)
def func(x):
    return 1/(q+1) * (1 - r0 * (np.sqrt(.25 + alpha * k * beta * x * (1 - (q+1) * x)) + .5))

# %%
# run system simulation
sirs = SIRSModels(mu=mu, gamma=gamma, theta=theta, beta=beta)
