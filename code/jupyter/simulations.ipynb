# %% [markdown]
# # Simulations

# %% [markdown]
# Savorgnan Enrico \
# University of Trieste, Italy \
# A. Y. 2024-2025
#
# *Thesis in Epidemiology*: \
# "A new model in behavioural epidemiology: SIRS model with social distancing"

# %%
from itertools import product
import os
from simulations import *

# %%
current_wd = os.getcwd()
print(f'Current working directory: {current_wd}')
# Out:
# Current working directory: D:\university\tesi\code

# %% [markdown]
# ### Simulation 0

# %%
# Parameters
# t = days
t_span = (0, 36500)

gamma = 1 / 7
mu = 1 / (80 * 365)

thetas = [1 / (10 * 3650), 1 / 365, 1 / 180, 1 / 30]
R0s = [1.05, 2, 5, 18]
a1s = [5, 95, 495]

a1 = 1 / 15
a2 = 1 / 90

beta_0 = [R0 * (mu + gamma) for R0 in R0s]
# Example usage
params = {
    't_span': t_span,
    'gamma': gamma,
    'mu': mu,
    'beta': 2 * (mu + gamma),
    'theta': 1 / 365,
    'a1': 1 / 15,
    'a2': 1 / 90,
    'k': 2,
}
print(f'R_0: {params["beta"] / (params["mu"] + params["gamma"])}')

# %%
for _i, (R0, theta) in enumerate(zip(R0s, thetas), start=1):
    params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'beta': R0 * (mu + gamma),
        'theta': theta,
        'a1': a1,
        'a2': a2,
        'k': 50,
    }
    print(f'Simulating models with R0={R0}, theta={theta}\n\n')
    solutions = []
    models = [sirs, sirs_zero_layer, sirs_one_layer, sirs_two_layer]
    for _k, model in enumerate(models):
        print(f'Simulating {model.__name__}\n\n')
        solution = simulate(model, params)
        solutions.append(solution)

    print('All simulations done!')
    plot_many_simulations(models, solutions, params)

# %% [markdown]
# ### Simulation 1

# %%
t_span = (0, 2000)

gamma = 1 / 7
mu = 1 / (80 * 365)

a1 = 1 / 15
a2 = 1 / 90

thetas = [1 / (10 * 3650), 1 / 365, 1 / 180, 1 / 30]
R0s = [1.05, 2, 5, 18]

R0_theta_list = list(zip(R0s, thetas))
models = [sirs, sirs_zero_layer, sirs_one_layer, sirs_two_layer]
params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        # 'beta': R0 * (mu + gamma),
        # 'theta': theta,
        'a1': a1,
        'a2': a2,
        'k': 50,
        'start_simulation': 0,
        'horizon': 200000
}
fig = simulation_1(models, R0_theta_list, params, show_cumulative_incidence=False)
save_figure(fig, path=current_wd+'/figures/', filename='simulation_1_1.png')

# %% [markdown]
# ### Simulation 2

# %%
t_span = (0, 365)

gamma = 1 / 7
mu = 1 / (80 * 365)

a1 = 1 / 15
a2 = 1 / 90

t_span = [0, 730]

params = {
    't_span': t_span,
    'gamma': gamma,
    'mu': mu,
    'beta': 18 * (mu + gamma),
    'theta': 1/365,
    'a1': a1,
    'a2': a2,
    'k': 50,
    'horizon': 2000
}

models = [sirs, sirs_one_layer_incidence, sirs_one_layer]

fig = simulation_2(models, params)
save_figure(fig, path=current_wd+'/figures/', filename='simulation_2_1.png')

# %% [markdown]
# ### Simulation 3a

# %%
t_span = (0, 1800)

gamma = 1 / 7
mu = 1 / (80 * 365)

a1 = 1 / 15
a2 = 1 / 90

R0s = [1.05, 2, 18]
thetas = [1 / (10 * 365), 1/365, 1 / 30]
R0_theta_list = list(product(R0s, thetas))
print(f'R0_theta_list: {R0_theta_list}')

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'a1': a1,
        'a2': a2,
        'k': 50,
}

models = [sirs, sirs_zero_layer, sirs_one_layer, sirs_two_layer]

fig = simulation_3a(models, params, R0_theta_list, show_cumulative_incidence=False)
if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/figures/', filename='simulation_3a_1.png')

# %% [markdown]
# ### Simulation 3b

# %%
t_span = (0, 3650)

gamma = 1 / 7
mu = 1 / (80 * 365)

a1s = [1/15, 1/30, 1/90, 1/180]
a2s = [1/30, 1/90, 1/180, 1/365]

a_list = list(zip(a1s, a2s))

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'beta': 1.5 * (mu + gamma),
        'theta': 1 / 3650,
        'k': 50,
}


models = [sirs_one_layer, sirs_two_layer]

fig = simulation_3b(models, params, a_list)
if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/figures/', filename='simulation_3b_1.png')

# %% [markdown]
# ### Simulation 4

# %%
# like simulation 3b but now I want to compare the two models with 2 layers for R0 = 5 and theta = 1/180 on the left and R0 = 1.5 and theta = 1/3650 on the right
t_span = (0, 3650)

gamma = 1 / 7
mu = 1 / (80 * 365)

R0s = [5, 1.5]
thetas = [1 / 180, 1 / 3650]

a1s = [1/15, 1/30, 1/90, 1/180]
a2s = [1/30, 1/90, 1/180, 1/365]
a_list = list(zip(a1s, a2s))

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        # 'beta': 1.5 * (mu + gamma)
        # 'theta': 1 / 3650,
        'k': 50,
}

models = [sirs_two_layer]

fig = simulation_4(models, params, R0s, thetas, a_list)
if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/figures/', filename='simulation_4_1.png')

# %% [markdown]
# ### Simulation 5

# %%
# study the effect of k on the models sirs with 2 layers of memory
t_span = (0, 1800)

gamma = 1 / 7
mu = 1 / (80 * 365)

k = [1, 10, 50, 100]
R0 = 2
theta = 1 / 365

a1 = 1 / 15
a2 = 1 / 90

models = [sirs_two_layer]

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'beta': R0 * (mu + gamma),
        'theta': theta,
        'a1': a1,
        'a2': a2,
}

fig = simulation_5(models, params, k, show_cumulative_incidence=False)

if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/figures/', filename='simulation_5_1.png')

# %% [markdown]
# ### Simulation 6

# %%
# Comparison of SIRS models with prevalence-based and incidence-based memory for different (R₀, θ) pairs

t_span = (0, 1200)

gamma = 1 / 7
mu = 1 / (80 * 365)

R0s = [1.05, 2, 5, 18]
thetas = [1 / (10 * 365), 1 / 365, 1 / 180, 1 / 30]

a1 = 1/15
a2 = 1/90
k = 50

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'a1': a1,
        'a2': a2,
        'k': k,
}

models = [sirs_one_layer, sirs_two_layer, sirs_one_layer_incidence, sirs_two_layer_incidence]

fig = simulation_6(models, params, R0s, thetas)

if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/figures/', filename='simulation_6_1.png')

# %% [markdown]
# ### Simulation 7

# %%
# Prevalence-based and incidence-based SIRS models with 1 and 2 layers of memory for different (a₁, a₂)

t_span = (0, 1200)

gamma = 1 / 7
mu = 1 / (80 * 365)

R0 = 2
theta = 1 / 365

k = 50

a1s = [1/15, 1/30, 1/90, 1/180]
a2s = [1/30, 1/90, 1/180, 1/365]

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'beta': R0 * (mu + gamma),
        'theta': theta,
        'k': k,
}

models = [sirs_one_layer, sirs_two_layer, sirs_one_layer_incidence, sirs_two_layer_incidence]

fig = simulation_7(models, params, a1s, a2s)
if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/figures/', filename='simulation_7_1.png')

# %% [markdown]
# ### Simulation 8

# %%
# Prevalence-based and incidence-based SIRS models with 1 and 2 layers of memory for different (k)

t_span = (0, 1200)

gamma = 1 / 7
mu = 1 / (80 * 365)

R0 = 2
theta = 1 / 365

a1 = 1/15
a2 = 1/90

ks = [1, 10, 50, 100]

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'beta': R0 * (mu + gamma),
        'theta': theta,
        'a1': a1,
        'a2': a2,
}

models = [sirs_one_layer, sirs_two_layer, sirs_one_layer_incidence, sirs_two_layer_incidence]

fig = simulation_8(models, params, ks)
if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/figures/', filename='simulation_8_1.png')
# Out:
# delta: 0
# Inner delta: 0.001
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 28
#      16 params = {
#      17         't_span': t_span,
#      18         'gamma': gamma,
#    (...)     23         'a2': a2,
#      24 }
#      26 models = [sirs_one_layer, sirs_two_layer, sirs_one_layer_incidence, sirs_two_layer_incidence]
# ---> 28 fig = simulation_8(models, params, ks)
#      29 if input('Do you want to save the figure? (y/n)').lower() == 'y':
#      30     print('Saving figure...')
#
# File D:\university\tesi\code\simulations.py:737, in simulation_8(models, params, ks, show_cumulative_incidence)
#     734 params['k'] = k_val
#     736 # Simulate the models for the current parameters
# --> 737 solutions = [simulate(m, params) for m in models]
#     739 # notes positions
#     740 x = 0.5
#
# File D:\university\tesi\code\utils.py:52, in simulate(model, params)
#      50 if delta == 0 or None:
#      51     beta_one = beta_one_layer(beta_0, k)
# ---> 52     sol = solve_ivp(model, t_span, X0, args=(beta_one, gamma, mu, theta, a1), dense_output=True)
#      53 else:
#      54     print(f'delta: {delta}, omega: {omega}')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\integrate\_ivp\ivp.py:621, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     618 if method in METHODS:
#     619     method = METHODS[method]
# --> 621 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     623 if t_eval is None:
#     624     ts = [t0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\integrate\_ivp\rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, t_bound, max_step, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\integrate\_ivp\base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\integrate\_ivp\base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\integrate\_ivp\ivp.py:593, in solve_ivp.<locals>.fun(t, x, fun)
#     592 def fun(t, x, fun=fun):
# --> 593     return fun(t, x, *args)
#
# File D:\university\tesi\code\models.py:56, in sirs_one_layer(t, X, beta_1, gamma, mu, theta, a, k, delta)
#      52 print('Inner delta:', delta)
#      54 if delta != 0:
#      55     # If seasonal forcing is present, pass time 't' to beta_1
# ---> 56     beta_1_func = beta_1(M, t)
#      57 else:
#      58     print(delta)
#
# TypeError: beta_one_layer.<locals>.beta_inside() takes 1 positional argument but 2 were given

# %% [markdown]
# ### Simulation 9

# %%
t_span = (0, 12000)

gamma = 1 / 7
mu = 1 / (80 * 365)

R0 = 2
theta = 1 / 365

a1 = 1/15
a2 = 1/90

deltas = [0.0001, 0.001, 0.1, 0.3]

params = {
        't_span': t_span,
        'gamma': gamma,
        'mu': mu,
        'beta': R0 * (mu + gamma),
        'theta': theta,
        'a1': a1,
        'a2': a2,
        'k': 1
}

models = [sirs_one_layer, sirs_two_layer, sirs_one_layer_incidence, sirs_two_layer_incidence]

fig = simulation_9(models, params, deltas)
if input('Do you want to save the figure? (y/n)').lower() == 'y':
    print('Saving figure...')
    save_figure(fig, path=current_wd+'/img/', filename='simulation_9_bb.png')
# Out:
# Saving figure...
# Figure saved to D:\university\tesi\code/img//simulation_9_bb.png
